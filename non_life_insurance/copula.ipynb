# %%
using Distributions
using Plots
u=rand(100)
v=rand(100)
ρ=0.8
norm=Normal()
x=quantile(norm, u)
z=quantile(norm,v)
#ρ*x+sqrt(1-ρ^2)*z
y=cdf(norm,ρ*x+sqrt(1-ρ^2)*z)
scatter(u, y,label="normal copula ρ=$ρ")

# %%
# Out:
# 2.0
